# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

data=pd.read_csv("hospital_patient_records.csv")
print(data)
# Out:
#      Patient_ID Patient_Name   Age  Gender        City        Department  \
# 0             1    Patient_1  51.0    Male  Coimbatore  General Medicine
# 1             2    Patient_2  54.0    Male     Chennai        Cardiology
# 2             3    Patient_3   8.0  Female  Coimbatore         Neurology
# 3             4    Patient_4  74.0  Female       Erode        Pediatrics
# 4             5    Patient_5  73.0    Male       Erode         Neurology
# ..          ...          ...   ...     ...         ...               ...
# 497         498  Patient_498  22.0    Male       Erode       Orthopedics
# 498         499  Patient_499  60.0    Male     Madurai               ENT
# 499         500  Patient_500  87.0  Female     Chennai       Orthopedics
# 500           2    Patient_2  54.0    Male     Chennai        Cardiology
# 501           3    Patient_3   8.0  Female  Coimbatore         Neurology
#
#         Doctor Admission_Date Discharge_Date       Disease Blood_Group  \
# ...

# %%
print(data.head())
print(data.tail())
print(data.shape)
print(data.columns)
print(data.info())
print(data.describe())
print(data.dtypes)
# Out:
#    Patient_ID Patient_Name   Age  Gender        City        Department  \
# 0           1    Patient_1  51.0    Male  Coimbatore  General Medicine
# 1           2    Patient_2  54.0    Male     Chennai        Cardiology
# 2           3    Patient_3   8.0  Female  Coimbatore         Neurology
# 3           4    Patient_4  74.0  Female       Erode        Pediatrics
# 4           5    Patient_5  73.0    Male       Erode         Neurology
#
#       Doctor Admission_Date Discharge_Date   Disease Blood_Group Insurance  \
# 0   Dr. Arun     2025-03-24     2025-03-27  Migraine          A+       Yes
# 1  Dr. Meena     2025-01-23     2025-01-30     Fever          A+       Yes
# 2   Dr. Ravi     2025-06-10     2025-06-20  Diabetes          O+        No
# 3  Dr. Kumar     2025-05-19     2025-05-21  Migraine          B+        No
# 4   Dr. Ravi     2025-05-21     2025-05-23    Asthma          O+        No
#
#    Bill_Amount  Paid_Amount Payment_Mode      Status
# ...

# %%
# Duplicates
print(data.drop_duplicates())
# Out:
#      Patient_ID Patient_Name   Age  Gender        City        Department  \
# 0             1    Patient_1  51.0    Male  Coimbatore  General Medicine
# 1             2    Patient_2  54.0    Male     Chennai        Cardiology
# 2             3    Patient_3   8.0  Female  Coimbatore         Neurology
# 3             4    Patient_4  74.0  Female       Erode        Pediatrics
# 4             5    Patient_5  73.0    Male       Erode         Neurology
# ..          ...          ...   ...     ...         ...               ...
# 495         496  Patient_496  72.0    Male     Chennai         Neurology
# 496         497  Patient_497  78.0  Female     Chennai               ENT
# 497         498  Patient_498  22.0    Male       Erode       Orthopedics
# 498         499  Patient_499  60.0    Male     Madurai               ENT
# 499         500  Patient_500  87.0  Female     Chennai       Orthopedics
#
#         Doctor Admission_Date Discharge_Date       Disease Blood_Group  \
# ...

# %%
data=data.drop_duplicates()
print(data)
# Out:
#      Patient_ID Patient_Name   Age  Gender        City        Department  \
# 0             1    Patient_1  51.0    Male  Coimbatore  General Medicine
# 1             2    Patient_2  54.0    Male     Chennai        Cardiology
# 2             3    Patient_3   8.0  Female  Coimbatore         Neurology
# 3             4    Patient_4  74.0  Female       Erode        Pediatrics
# 4             5    Patient_5  73.0    Male       Erode         Neurology
# ..          ...          ...   ...     ...         ...               ...
# 495         496  Patient_496  72.0    Male     Chennai         Neurology
# 496         497  Patient_497  78.0  Female     Chennai               ENT
# 497         498  Patient_498  22.0    Male       Erode       Orthopedics
# 498         499  Patient_499  60.0    Male     Madurai               ENT
# 499         500  Patient_500  87.0  Female     Chennai       Orthopedics
#
#         Doctor Admission_Date Discharge_Date       Disease Blood_Group  \
# ...

# %%
print(data.shape)
# Out:
# (500, 16)

# %%
data.isnull()
# Out:
#      Patient_ID  Patient_Name    Age  Gender   City  Department  Doctor  \
# 0         False         False  False   False  False       False   False
# 1         False         False  False   False  False       False   False
# 2         False         False  False   False  False       False   False
# 3         False         False  False   False  False       False   False
# 4         False         False  False   False  False       False   False
# ..          ...           ...    ...     ...    ...         ...     ...
# 495       False         False  False   False  False       False   False
# 496       False         False  False   False  False       False   False
# 497       False         False  False   False  False       False   False
# 498       False         False  False   False  False       False   False
# 499       False         False  False   False  False       False   False
#
#      Admission_Date  Discharge_Date  Disease  Blood_Group  Insurance  \
# ...

# %%
data.isnull().sum()
# Out:
# Patient_ID        0
# Patient_Name      0
# Age               1
# Gender            0
# City              0
# Department        0
# Doctor            1
# Admission_Date    0
# Discharge_Date    0
# Disease           0
# Blood_Group       0
# Insurance         1
# Bill_Amount       0
# Paid_Amount       0
# Payment_Mode      0
# Status            0
# dtype: int64

# %%
data[data["Insurance"].isnull()]
# Out:
#     Patient_ID Patient_Name   Age  Gender        City Department    Doctor  \
# 60          61   Patient_61  33.0  Female  Coimbatore        ENT  Dr. Ravi
#
#    Admission_Date Discharge_Date Disease Blood_Group Insurance  Bill_Amount  \
# 60     2025-01-04     2025-01-09   Fever          O+       NaN        26569
#
#     Paid_Amount Payment_Mode      Status
# 60        21255         Card  Discharged

# %%
data["Age"]=data["Age"].fillna(data["Age"].median())
print(data.iloc[70])
# Out:
# Patient_ID                71
# Patient_Name      Patient_71
# Age                     42.0
# Gender                Female
# City                   Erode
# Department               ENT
# Doctor             Dr. Priya
# Admission_Date    2025-05-06
# Discharge_Date    2025-05-07
# Disease                Fever
# Blood_Group               B+
# Insurance                Yes
# Bill_Amount            30422
# Paid_Amount            24337
# Payment_Mode            Cash
# Status            Discharged
# Name: 70, dtype: object

# %%
data["Doctor"]=data["Doctor"].fillna("Not Assigned")
data.isnull().sum()
# Out:
# Patient_ID        0
# Patient_Name      0
# Age               1
# Gender            0
# City              0
# Department        0
# Doctor            0
# Admission_Date    0
# Discharge_Date    0
# Disease           0
# Blood_Group       0
# Insurance         0
# Bill_Amount       0
# Paid_Amount       0
# Payment_Mode      0
# Status            0
# dtype: int64

# %%
data["Insurance"]=data["Insurance"].fillna("Not Confirmed")
print(data.loc[60])
# Out:
# Patient_ID                   61
# Patient_Name         Patient_61
# Age                        33.0
# Gender                   Female
# City                 Coimbatore
# Department                  ENT
# Doctor                 Dr. Ravi
# Admission_Date       2025-01-04
# Discharge_Date       2025-01-09
# Disease                   Fever
# Blood_Group                  O+
# Insurance         Not Confirmed
# Bill_Amount               26569
# Paid_Amount               21255
# Payment_Mode               Card
# Status               Discharged
# Name: 60, dtype: object

# %%
data.isnull().sum()
# Out:
# Patient_ID        0
# Patient_Name      0
# Age               0
# Gender            0
# City              0
# Department        0
# Doctor            0
# Admission_Date    0
# Discharge_Date    0
# Disease           0
# Blood_Group       0
# Insurance         0
# Bill_Amount       0
# Paid_Amount       0
# Payment_Mode      0
# Status            0
# dtype: int64

# %%
print(data)
# Out:
#      Patient_ID Patient_Name   Age  Gender        City        Department  \
# 0             1    Patient_1  51.0    Male  Coimbatore  General Medicine
# 1             2    Patient_2  54.0    Male     Chennai        Cardiology
# 2             3    Patient_3   8.0  Female  Coimbatore         Neurology
# 3             4    Patient_4  74.0  Female       Erode        Pediatrics
# 4             5    Patient_5  73.0    Male       Erode         Neurology
# ..          ...          ...   ...     ...         ...               ...
# 497         498  Patient_498  22.0    Male       Erode       Orthopedics
# 498         499  Patient_499  60.0    Male     Madurai               ENT
# 499         500  Patient_500  87.0  Female     Chennai       Orthopedics
# 500           2    Patient_2  54.0    Male     Chennai        Cardiology
# 501           3    Patient_3   8.0  Female  Coimbatore         Neurology
#
#         Doctor Admission_Date Discharge_Date       Disease Blood_Group  \
# ...

# %%
print(data.dtypes)
# Out:
# Patient_ID          int64
# Patient_Name          str
# Age               float64
# Gender                str
# City                  str
# Department            str
# Doctor                str
# Admission_Date        str
# Discharge_Date        str
# Disease               str
# Blood_Group           str
# Insurance             str
# Bill_Amount         int64
# Paid_Amount         int64
# Payment_Mode          str
# Status                str
# dtype: object

# %%
data["Age"]=data["Age"].astype("int64")
data["Admission_Date"]=data["Admission_Date"].astype("datetime64[ns]")
data["Discharge_Date"]=data["Discharge_Date"].astype("datetime64[ns]")

# %%
print(data.dtypes)
# Out:
# Patient_ID                 int64
# Patient_Name                 str
# Age                        int64
# Gender                       str
# City                         str
# Department                   str
# Doctor                       str
# Admission_Date    datetime64[ns]
# Discharge_Date    datetime64[ns]
# Disease                      str
# Blood_Group                  str
# Insurance                    str
# Bill_Amount                int64
# Paid_Amount                int64
# Payment_Mode                 str
# Status                       str
# dtype: object

# %%
data[data.duplicated()]
# Out:
#      Patient_ID Patient_Name   Age  Gender        City  Department     Doctor  \
# 500           2    Patient_2  54.0    Male     Chennai  Cardiology  Dr. Meena
# 501           3    Patient_3   8.0  Female  Coimbatore   Neurology   Dr. Ravi
#
#     Admission_Date Discharge_Date   Disease Blood_Group Insurance  \
# 500     2025-01-23     2025-01-30     Fever          A+       Yes
# 501     2025-06-10     2025-06-20  Diabetes          O+        No
#
#      Bill_Amount  Paid_Amount Payment_Mode      Status
# 500      37113.0        29690          UPI  Discharged
# 501       4052.0         3241         Cash  Discharged

# %%
data[data["Age"]<=0]
data[data["Age"]>=100]
# Out:
#     Patient_ID Patient_Name  Age  Gender   City  Department     Doctor  \
# 10          11   Patient_11  210  Female  Salem  Cardiology  Dr. Meena
#
#    Admission_Date Discharge_Date Disease Blood_Group Insurance  Bill_Amount  \
# 10     2025-02-03     2025-02-07  Asthma          O+       Yes        11902
#
#     Paid_Amount Payment_Mode      Status
# 10         9521         Card  Discharged

# %%
data[data.duplicated()]
# Out:
#      Patient_ID Patient_Name  Age  Gender        City  Department     Doctor  \
# 500           2    Patient_2   54    Male     Chennai  Cardiology  Dr. Meena
# 501           3    Patient_3    8  Female  Coimbatore   Neurology   Dr. Ravi
#
#     Admission_Date Discharge_Date   Disease Blood_Group Insurance  \
# 500     2025-01-23     2025-01-30     Fever          A+       Yes
# 501     2025-06-10     2025-06-20  Diabetes          O+        No
#
#      Bill_Amount  Paid_Amount Payment_Mode      Status
# 500        37113        29690          UPI  Discharged
# 501         4052         3241         Cash  Discharged

# %%
data.drop_duplicates()
# Out:
#      Patient_ID Patient_Name  Age  Gender        City        Department  \
# 0             1    Patient_1   51    Male  Coimbatore  General Medicine
# 1             2    Patient_2   54    Male     Chennai        Cardiology
# 2             3    Patient_3    8  Female  Coimbatore         Neurology
# 3             4    Patient_4   74  Female       Erode        Pediatrics
# 4             5    Patient_5   73    Male       Erode         Neurology
# ..          ...          ...  ...     ...         ...               ...
# 495         496  Patient_496   72    Male     Chennai         Neurology
# 496         497  Patient_497   78  Female     Chennai               ENT
# 497         498  Patient_498   22    Male       Erode       Orthopedics
# 498         499  Patient_499   60    Male     Madurai               ENT
# 499         500  Patient_500   87  Female     Chennai       Orthopedics
#
#         Doctor Admission_Date Discharge_Date       Disease Blood_Group  \
# ...

# %%
data.loc[data["Age"]>100, "Age"]=np.nan

# %%
data.iloc[10]
# Out:
# Patient_ID                11
# Patient_Name      Patient_11
# Age                      NaN
# Gender                Female
# City                   Salem
# Department        Cardiology
# Doctor             Dr. Meena
# Admission_Date    2025-02-03
# Discharge_Date    2025-02-07
# Disease               Asthma
# Blood_Group               O+
# Insurance                Yes
# Bill_Amount            11902
# Paid_Amount             9521
# Payment_Mode            Card
# Status            Discharged
# Name: 10, dtype: object

# %%
data[data["Discharge_Date"]< data["Admission_Date"]]
# Out:
#     Patient_ID Patient_Name   Age Gender     City  Department     Doctor  \
# 80          81   Patient_81  60.0   Male  Madurai  Pediatrics  Dr. Meena
#
#    Admission_Date Discharge_Date   Disease Blood_Group Insurance  Bill_Amount  \
# 80     2025-02-17     2025-02-16  Fracture          O+        No        48538
#
#     Paid_Amount Payment_Mode      Status
# 80        38830         Cash  Discharged

# %%
data.loc[data["Discharge_Date"]< data["Admission_Date"], "Discharge_Date"]=np.nan

# %%
data.iloc[80]
# Out:
# Patient_ID                81
# Patient_Name      Patient_81
# Age                     60.0
# Gender                  Male
# City                 Madurai
# Department        Pediatrics
# Doctor             Dr. Meena
# Admission_Date    2025-02-17
# Discharge_Date           NaN
# Disease             Fracture
# Blood_Group               O+
# Insurance                 No
# Bill_Amount            48538
# Paid_Amount            38830
# Payment_Mode            Cash
# Status            Discharged
# Name: 80, dtype: object

# %%
data[data["Bill_Amount"]<=0]
# Out:
#     Patient_ID Patient_Name   Age Gender     City  Department    Doctor  \
# 40          41   Patient_41  24.0   Male  Madurai  Pediatrics  Dr. Ravi
#
#    Admission_Date Discharge_Date   Disease Blood_Group Insurance  Bill_Amount  \
# 40     2025-03-09     2025-03-10  Diabetes          O+        No         -500
#
#     Paid_Amount Payment_Mode      Status
# 40        16790          UPI  Discharged

# %%
data.loc[data["Bill_Amount"]< 0, "Bill_Amount"]=np.nan
data.iloc[40]
# Out:
# Patient_ID                41
# Patient_Name      Patient_41
# Age                     24.0
# Gender                  Male
# City                 Madurai
# Department        Pediatrics
# Doctor              Dr. Ravi
# Admission_Date    2025-03-09
# Discharge_Date    2025-03-10
# Disease             Diabetes
# Blood_Group               O+
# Insurance                 No
# Bill_Amount              NaN
# Paid_Amount            16790
# Payment_Mode             UPI
# Status            Discharged
# Name: 40, dtype: object

# %%
data.loc[data["Bill_Amount"]< 0, "Bill_Amount"]=np.nan

# %%
data["Disease"].unique()
# Out:
# <StringArray>
# ['Migraine', 'Fever', 'Diabetes', 'Asthma', 'Fracture', 'Hypertension']
# Length: 6, dtype: str

# %%
data["City"].unique()
# Out:
# <StringArray>
# [  'Coimbatore',      'Chennai',        'Erode',      'Madurai',
#         'Salem',       'Trichy',          'CBE', ' coimbatore ']
# Length: 8, dtype: str

# %%
data["City"]=data["City"].replace({
"coimbatore": "Coimbatore",
"CBE":"Coimbatore"
})

# %%
data["City"].str.strip()
# Out:
# 0      Coimbatore
# 1         Chennai
# 2      Coimbatore
# 3           Erode
# 4           Erode
#           ...
# 497         Erode
# 498       Madurai
# 499       Chennai
# 500       Chennai
# 501    Coimbatore
# Name: City, Length: 502, dtype: str

# %%
data["City"]=data["City"].replace(" coimbatore ","Coimbatore")

# %%
data["City"].unique()
# Out:
# <StringArray>
# ['Coimbatore', 'Chennai', 'Erode', 'Madurai', 'Salem', 'Trichy']
# Length: 6, dtype: str

# %%
data["Department"].unique()
# Out:
# <StringArray>
# ['General Medicine',       'Cardiology',        'Neurology',
#        'Pediatrics',              'ENT',      'Orthopedics',
#      ' Cardiology ',       'cardiology']
# Length: 8, dtype: str

# %%
data["Department"]=data["Department"].replace({
    " Cardiology ":"Cardiology",
    "cardiology":"Cardiology"
})

# %%
data["Department"].unique()
# Out:
# <StringArray>
# ['General Medicine',       'Cardiology',        'Neurology',
#        'Pediatrics',              'ENT',      'Orthopedics']
# Length: 6, dtype: str

# %%
data["Status"].unique()
# Out:
# <StringArray>
# ['Discharged']
# Length: 1, dtype: str

# %%
data["Payment_Mode"].unique()
# Out:
# <StringArray>
# ['Cash', 'UPI', 'Card']
# Length: 3, dtype: str

# %%
data["Insurance"].unique()
# Out:
# <StringArray>
# ['Yes', 'No', nan]
# Length: 3, dtype: str

# %%
data["Blood_Group"].unique()
# Out:
# <StringArray>
# ['A+', 'O+', 'B+', 'AB+']
# Length: 4, dtype: str

# %%
data["Gender"].unique()
# Out:
# <StringArray>
# ['Male', 'Female', 'M', 'female']
# Length: 4, dtype: str

# %%
data["Gender"]=data["Gender"].replace({
    "M":"Male",
    "female":"Female"
})

# %%
data["Gender"].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
print(data)
# Out:
#      Patient_ID Patient_Name   Age  Gender        City        Department  \
# 0             1    Patient_1  51.0    Male  Coimbatore  General Medicine
# 1             2    Patient_2  54.0    Male     Chennai        Cardiology
# 2             3    Patient_3   8.0  Female  Coimbatore         Neurology
# 3             4    Patient_4  74.0  Female       Erode        Pediatrics
# 4             5    Patient_5  73.0    Male       Erode         Neurology
# ..          ...          ...   ...     ...         ...               ...
# 497         498  Patient_498  22.0    Male       Erode       Orthopedics
# 498         499  Patient_499  60.0    Male     Madurai               ENT
# 499         500  Patient_500  87.0  Female     Chennai       Orthopedics
# 500           2    Patient_2  54.0    Male     Chennai        Cardiology
# 501           3    Patient_3   8.0  Female  Coimbatore         Neurology
#
#         Doctor Admission_Date Discharge_Date       Disease Blood_Group  \
# ...

# %%
data["Department"].str.strip()
data["Department"]=data["Department"].str.strip()
data["Department"].unique()
# Out:
# <StringArray>
# ['General Medicine',       'Cardiology',        'Neurology',
#        'Pediatrics',              'ENT',      'Orthopedics']
# Length: 6, dtype: str

# %%
data["Patient_Name"].str.strip()
data["Patient_Name"]=data["Patient_Name"].str.strip()
data["Patient_Name"].unique()
# Out:
# <StringArray>
# [  'Patient_1',   'Patient_2',   'Patient_3',   'Patient_4',   'Patient_5',
#    'Patient_6',   'Patient_7',   'Patient_8',   'Patient_9',  'Patient_10',
#  ...
#  'Patient_491', 'Patient_492', 'Patient_493', 'Patient_494', 'Patient_495',
#  'Patient_496', 'Patient_497', 'Patient_498', 'Patient_499', 'Patient_500']
# Length: 500, dtype: str

# %%
data["Doctor"].str.strip()
data["Doctor"]=data["Doctor"].str.strip()
data["Doctor"].unique()
# Out:
# <StringArray>
# ['Dr. Arun', 'Dr. Meena', 'Dr. Ravi', 'Dr. Kumar', 'Dr. Priya', nan]
# Length: 6, dtype: str

# %%
data["Payment_Mode"].str.strip()
data["Payment_Mode"]=data["Payment_Mode"].str.strip()
data["Payment_Mode"].unique()
# Out:
# <StringArray>
# ['Cash', 'UPI', 'Card']
# Length: 3, dtype: str

# %%
data["Status"].str.strip()
data["Status"]=data["Status"].str.strip()
data["Status"].unique()
# Out:
# <StringArray>
# ['Discharged']
# Length: 1, dtype: str

# %%
data["Disease"].str.strip()
data["Disease"]=data["Disease"].str.strip()
data["Disease"].unique()
# Out:
# <StringArray>
# ['Migraine', 'Fever', 'Diabetes', 'Asthma', 'Fracture', 'Hypertension']
# Length: 6, dtype: str

# %%
data["Blood_Group"].str.strip()
data["Blood_Group"]=data["Blood_Group"].str.strip()
data["Blood_Group"].unique()
# Out:
# <StringArray>
# ['A+', 'O+', 'B+', 'AB+']
# Length: 4, dtype: str

# %%
data["Insurance"].str.strip()
data["Insurance"]=data["Insurance"].str.strip()
data["Insurance"].unique()
# Out:
# <StringArray>
# ['Yes', 'No', nan]
# Length: 3, dtype: str

# %%
data["Gender"].str.strip()
data["Gender"]=data["Gender"].str.strip()
data["Gender"].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
data["Age"]=data["Age"].astype("Int64")
print(data)
# Out:
#      Patient_ID Patient_Name  Age  Gender        City        Department  \
# 0             1    Patient_1   51    Male  Coimbatore  General Medicine
# 1             2    Patient_2   54    Male     Chennai        Cardiology
# 2             3    Patient_3    8  Female  Coimbatore         Neurology
# 3             4    Patient_4   74  Female       Erode        Pediatrics
# 4             5    Patient_5   73    Male       Erode         Neurology
# ..          ...          ...  ...     ...         ...               ...
# 497         498  Patient_498   22    Male       Erode       Orthopedics
# 498         499  Patient_499   60    Male     Madurai               ENT
# 499         500  Patient_500   87  Female     Chennai       Orthopedics
# 500           2    Patient_2   54    Male     Chennai        Cardiology
# 501           3    Patient_3    8  Female  Coimbatore         Neurology
#
#         Doctor Admission_Date Discharge_Date       Disease Blood_Group  \
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(2)

# %%
data=data.drop_duplicates()
print(data)
# Out:
#      Patient_ID Patient_Name  Age  Gender        City        Department  \
# 0             1    Patient_1   51    Male  Coimbatore  General Medicine
# 1             2    Patient_2   54    Male     Chennai        Cardiology
# 2             3    Patient_3    8  Female  Coimbatore         Neurology
# 3             4    Patient_4   74  Female       Erode        Pediatrics
# 4             5    Patient_5   73    Male       Erode         Neurology
# ..          ...          ...  ...     ...         ...               ...
# 495         496  Patient_496   72    Male     Chennai         Neurology
# 496         497  Patient_497   78  Female     Chennai               ENT
# 497         498  Patient_498   22    Male       Erode       Orthopedics
# 498         499  Patient_499   60    Male     Madurai               ENT
# 499         500  Patient_500   87  Female     Chennai       Orthopedics
#
#         Doctor Admission_Date Discharge_Date       Disease Blood_Group  \
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Department Wise Diesease Count
data["Department"].value_counts()
# Out:
# Department
# Orthopedics         101
# Pediatrics           85
# Neurology            83
# Cardiology           81
# General Medicine     76
# ENT                  74
# Name: count, dtype: int64

# %%
# Disease wise Patient Count
data["Disease"].value_counts()
# Out:
# Disease
# Asthma          97
# Diabetes        90
# Migraine        89
# Fever           83
# Hypertension    74
# Fracture        67
# Name: count, dtype: int64

# %%
# Gender Distribution
data["Gender"].value_counts()
# Out:
# Gender
# Male      260
# Female    240
# Name: count, dtype: int64

# %%
# Average Bill
data["Bill_Amount"].mean().round(2)
# Out:
# np.float64(25682.21)

# %%
# Patment Status
data["Payment_Mode"].value_counts()
# Out:
# Payment_Mode
# Cash    177
# Card    170
# UPI     153
# Name: count, dtype: int64

# %%
# Insurance Details
data["Insurance"].value_counts()
# Out:
# Insurance
# Yes    269
# No     230
# Name: count, dtype: int64

# %%
# Doctor-wise-Patients
data["Doctor"].value_counts()
# Out:
# Doctor
# Dr. Priya    110
# Dr. Kumar    105
# Dr. Meena     97
# Dr. Arun      95
# Dr. Ravi      92
# Name: count, dtype: int64

# %%
# Histogram
sns.histplot(data["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# Box Plot
sns.boxplot(x=data["Department"], y=data["Bill_Amount"])
# Out:
# <Axes: xlabel='Department', ylabel='Bill_Amount'>

# %%
# Count Plot
sns.countplot(x=data["Gender"])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# Bivariate->> Scatter Plot
sns.scatterplot(x=data["Bill_Amount"], y=data["Paid_Amount"])
# Out:
# <Axes: xlabel='Bill_Amount', ylabel='Paid_Amount'>

# %%
# Bar Plot
sns.barplot(x=data["Gender"], hue=data["Disease"])
# Out:
# <Axes: xlabel='Gender'>

# %%
# Line Plot
sns.lineplot(x="Gender", y="Bill_Amount",data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='Bill_Amount'>
